# %%
html("<h1 style='color: orange'>Графики: Базовое</h1>")
# Out:
# <h1 style='color: orange'>Графики: Базовое</h1>

# %%
# см. офиц. документацию:
#     http://doc.sagemath.org/html/ru/tutorial/tour_plotting.html
#     --- в стиле "по шагам - берем и пробуем"
# неплохой туториал от IBML: 
#     https://www.ibm.com/developerworks/ru/library/cl-sage_3/index.html
#     --- более обзорно, более структурированно

# %%
html("<h1 style='color: orange'>Графические примитивы</h1>")
# Out:
# <h1 style='color: orange'>Графические примитивы</h1>

# %%
html("<h3 style='color: green;'>Графические примитивы: Сектор круга</h3><br />")
# Out:
# <h3 style='color: green;'>Графические примитивы: Сектор круга</h3><br />

# %%
bl = disk((0.0,0.0), 1, (pi, 3*pi/2), color='yellow')
tr = disk((0.0,0.0), 1, (0, pi/2), color='yellow')
tl = disk((0.0,0.0), 1, (pi/2, pi), color='black')
br = disk((0.0,0.0), 1, (3*pi/2, 2*pi), color='black')
P  = tl+tr+bl+br
P.show(xmin=-2,xmax=2,ymin=-2,ymax=2)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
bl = disk((0.0,0.0), 1, (pi, 3*pi/2), rgbcolor=(1,1,0))
bl.show()
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
html("<h3 style='color: green;'>Графические примитивы: Стрелка</h3><br />")
# Out:
# <h3 style='color: green;'>Графические примитивы: Стрелка</h3><br />

# %%
arrow((0,0), (1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
html("<h3 style='color: green;'>Графические примитивы: Эллиптическая кривая</h3><br />")
# Out:
# <h3 style='color: green;'>Графические примитивы: Эллиптическая кривая</h3><br />

# %%
E = EllipticCurve([0,-1])
plot(E, (1, 4), color=hue(0.6))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
html("<h3 style='color: green;'>Окружность</h3><br />")
# Out:
# <h3 style='color: green;'>Окружность</h3><br />

# %%
circle((0,0), 1, rgbcolor=(1,1,0))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
html("<h3 style='color: green;'>Круг</h3><br />")
# Out:
# <h3 style='color: green;'>Круг</h3><br />

# %%
circle((0,0), 1, rgbcolor=(1,1,0), fill=True)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
c = circle((0,0), 1, rgbcolor=(1,1,0))
c.show() # или show(c)
c.save('E:\\filename.png') # сохранит график в файл
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
# оси могут иметь разный масштаб, из-за чего окружность отобразится как эллипс
c.show(aspect_ratio=1) 
# show(c, aspect_ratio=1)
# c.save('filename.png', aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
html("<h1 style='color: orange'>Просто график базовой функции</h1>")
# Out:
# <h1 style='color: orange'>Просто график базовой функции</h1>

# %%
print("просто график базовой функции")
plot(cos, (-5,5))
# Out:
# просто график базовой функции
# Graphics object consisting of 1 graphics primitive

# %%
html("<h1 style='color: orange'>Параметрический график</h1>")
# Out:
# <h1 style='color: orange'>Параметрический график</h1>

# %%
# для параметрического задания уже придется объявить переменную x, 
# т.к. она упоминается при задании функции графика
x = var('x')
parametric_plot( 	(cos(x), sin(x)^3)
                    ,(x, 0, 2*pi)
                    ,rgbcolor=hue(0.6)
            )
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
html("<h1 style='color: orange'>График функции, заданной неявно</h1>")
# Out:
# <h1 style='color: orange'>График функции, заданной неявно</h1>

# %%
var("x y")
implicit_plot(x**2 + y**2 - 1, (x, -3, 3), (y, -3, 3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var("x y z")
implicit_plot3d(x**2 + y**2 + z**2 -1, (x, -3, 3), (y, -3, 3), (z, -3, 3))
# Out:
# Graphics3d Object

# %%
html("<h1 style='color: orange'>Линия по массиву точек</h1>")
# Out:
# <h1 style='color: orange'>Линия по массиву точек</h1>

# %%
v = [(sin(x),x) for x in srange(-2*float(pi),2*float(pi),0.1)]
line(v)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
v = [(tan(x),x) for x in srange(-2*float(pi),2*float(pi),0.01)]
show(line(v), xmin=-20, xmax=20)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
html("<h1 style='color: orange'>Фигура по массиву точек (полигон)</h1>")
# Out:
# <h1 style='color: orange'>Фигура по массиву точек (полигон)</h1>

# %%
# график по массиву точек (полигон):
L = [
        [
                -1+cos(pi*i/100)*(1+cos(pi*i/100))
            ,	2*sin(pi*i/100)*(1-cos(pi*i/100))
         ] for i in range(200)
    ]
p = polygon(L, rgbcolor=(1/8,3/4,1/2))
p
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
html("<h1 style='color: orange'>Контурный график</h1>")
# Out:
# <h1 style='color: orange'>Контурный график</h1>

# %%
f = lambda x,y: cos(x*y)
contour_plot(f, (-4, 4), (-4, 4))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
html("<h1 style='color: orange'>График неравенств</h1>")
# Out:
# <h1 style='color: orange'>График неравенств</h1>

# %%
region_plot(
		x*(x-1)*(x+1) + y^2 < 0
	,	(x, -3, 2)
	,	(y, -3, 3)
	,	incol='lightblue'
	,	bordercol='gray'
	,	borderwidth=10
	, plot_points=50
)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
region_plot([
					x*(x-1)*(x+1) + y^2 < 0
				,	x > -1
			]
			, (x, -3, 2)
			, (y, -3, 3)
			, incol='lightblue'
			, plot_points=50
		)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
region_plot([x^2 + y^2 < 4, x > -1], (x,-2,2), (y,-2,2),
             incol='lightblue', bordercol='gray', plot_points=200)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
s, t = var('s, t')
region_plot(s > 0, (t,-2,2), (s,-2,2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
region_plot(s>0,(s,-2,2),(t,-2,2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
region_plot(lambda x, y: x^2 + y^2 < 1 or x < y, (x,-2,2), (y,-2,2), plot_points=400)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
region_plot([x^2 + y^2 < 1, x< y], (x,-2,2), (y,-2,2), plot_points=400)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
region_plot(sin(x) * sin(y) >= 1/4, (x,-10,10), (y,-10,10),
                  incol='yellow', bordercol='black',
                   borderstyle='dashed', plot_points=250)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
region_plot(x^2 + y^3 < 2, (x,-2,2), (y,-2,2), incol='lightblue', bordercol='gray')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
html("<h1 style='color: orange'>График функции комплексной переменной</h1>")
# Out:
# <h1 style='color: orange'>График функции комплексной переменной</h1>

# %%
complex_plot(zeta, (-30,30), (-30,30))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
complex_plot(sqrt(x), (-5, 5), (-5, 5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
complex_plot(sin(x), (-5, 5), (-5, 5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(z) = z^5 + z - 1 + 1/z
complex_plot(f, (-3, 3), (-3, 3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
html("<h1 style='color: orange'>График для метода Эйлера</h1>")
# Out:
# <h1 style='color: orange'>График для метода Эйлера</h1>

# %%
f = lambda z: z[2]        # f(t,x,y) = y
g = lambda z: -sin(z[1])  # g(t,x,y) = -sin(x)
P = eulers_method_2x2_plot(f,g, 0.0, 0.75, 0.0, 0.1, 1.0)
show(P[0] + P[1])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
show(html("<h1>Исключение точек на графике</h1>"))
sols = solve(tan(x) == 0, x, to_poly_solve='force')
show(sols)

excl_expr = sols[0].rhs()
excl_const = excl_expr.args()[0]
xmax=20
excl_list = [excl_expr({excl_const: i}) for i in range(0, ceil(xmax/pi))]
show(excl_list)

y(x)= 1 / tan(x)
plot(y, (x, -1, xmax), ymin=-20.0, ymax=20.0, exclude=excl_list)
# Out:
# <h1>Исключение точек на графике</h1>
# [x == pi*z1992]
# [0, pi, 2*pi, 3*pi, 4*pi, 5*pi, 6*pi]
# Graphics object consisting of 8 graphics primitives
